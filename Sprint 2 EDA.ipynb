# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment</b>
#
# Hi, it's Sveta again. I was the reviewer on your previous project, and I am going to review this one as well.
#
# I will be using the same color marking:
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ✔️</b>
#
# Great solutions and ideas that can and should be used in the future are in green comments.
# </div>
#
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ⚠️</b>
#
# Yellow color indicates what should be optimized. This is not necessary, but it will be great if you make changes to this project.
# </div>
#
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# Issues that need to be corrected to get right results are indicated in red comments. Note that the project cannot be accepted until these issues are resolved.
# </div>
#
# <hr>
#
# **Please, use some color other than those listed to highlight answers to my comments.**
# I would also ask you **not to change, move or delete my comments** so that it would be easier for me to navigate during the next review.
#
# In addition, my comments are defined as headings.
# They can mess up the content; however, they are convenient, since you can immediately go to them. I will remove the headings from my comments in the next review.
#
#
#
# <hr>
#
# <font color='dodgerblue'>**A few words about the project:**</font> everything looks very good, you did a great job here. There're several issues that need your attention, but it will not take much time :)
#
#
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 2</b>
#
#
# Thank you for the updates! I've left a few comments titled as **Reviewer's comment 2**. Please take a look :)
#
#
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Student's comment 2</b>
#
#
#
# Thank you for your feedback!

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 3</b>
#
#
# I apologize for a long reply. I did not leave any new comments this time because everything is great. Therefore, I can accept the project. Congratulations! 😊
#
#
# Good luck!
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment ❌</b>
#
# First things first. The introduction is the initial paragraph that each project, each essay or any article should have. It is important to write an introductory part, because it gives an idea about the content of the project. Please, add project and data descriptions.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# Great!
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment</h2>
#
# This project analyzes consumer behavior in online grocery shopping using data from Instacart, which covers over 3 million orders from more than 200,000 users. The dataset is divided into five tables: orders, products, order_products, aisles, and departments, each providing insights into user purchases, product popularity, and shopping patterns. The analysis focuses on identifying shopping frequency, popular and frequently reordered products, and variations in shopping behavior by time and day. Through data preprocessing, visualization, and analysis, the project aims to uncover trends that can improve inventory management, marketing strategies, and the overall shopping experience on the Instacart platform.
# </div>
#
#
#
# <font color='red'> This code is used to change text color. </font>

# %%
# Imports
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sb

# %%
# read in data frame and display info
orders = pd.read_csv('/datasets/instacart_orders.csv', sep=';')
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB

# %%
# read in data frame and display info
products = pd.read_csv('/datasets/products.csv', sep=';')
products.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
# read in data frame and display info
departments = pd.read_csv('/datasets/departments.csv', sep=';')
departments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes

# %%
# read in data frame and display info
aisles = pd.read_csv('/datasets/aisles.csv', sep=';')
aisles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
# read in data frame and display info
order_products = pd.read_csv('/datasets/order_products.csv', sep=';')
order_products.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment</h2>
#
#
# The dataset comprises five key components: orders, products, departments, aisles, and order_products, each with its specific attributes and data types. A preliminary examination reveals the following insights:
#
# Orders DataFrame: It holds nearly half a million entries across six columns, primarily integer types, except for days_since_prior_order, which is a float, reflecting the interval in days since the last order. There are no null values in the majority of the columns, ensuring a robust dataset for analyzing order patterns.
#
# Products DataFrame: Contains information on nearly 50,000 products. It shows a shortfall in the product_name column, indicating missing product names that need addressing to ensure data integrity for product-based analysis.
#
# Departments and Aisles DataFrames: Smaller in size, these tables categorize products into broader shopping categories and are fully populated, offering a comprehensive view of the store layout and product classification without any missing values.
#
# Order_Products DataFrame: The largest of the datasets with over 4.5 million entries. It links orders to specific products, including data on the order sequence and whether the product was reordered. A minor discrepancy is observed in the add_to_cart_order column with a few missing values, indicating some data cleaning might be necessary.
#
# In summary, the datasets provide a comprehensive foundation for analyzing Instacart's grocery shopping patterns, with minor data cleaning requirements in the products and order_products datasets to address missing values. The extensive range of data offers a promising avenue for in-depth analysis of consumer behavior, product popularity, and ordering dynamics.
# </div>
#
#
#
# <font color='red'> This code is used to change text color. </font>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>  Reviewer's comment ⚠️</b>
#
#
#
# An intermediate conclusion would not be redundant here :)
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# Very good!
#
#
# </div>

# %% [markdown]
# ## Find and remove duplicate values (and describe why you make your choices)

# %% [markdown]
# ### `orders` data frame

# %%
# Check for duplicated orders

# prints the row and order_id of each duplicate (we ignore the first copy of a duplicate)
# print(orders[orders.duplicated(subset='order_id')].order_id)
print("Count of duplicated items:")
print(orders.duplicated().sum())
print()
print("List any order_id that appears more than once and its count:")
value_counts = orders['order_id'].value_counts()
print(value_counts[value_counts > 1])
# Out:
# Count of duplicated items:
# 15
#
# List any order_id that appears more than once and its count:
# 2125197    2
# 1782114    2
# 1286742    2
# 391768     2
# 1021560    2
# 2232988    2
# 408114     2
# 2282673    2
# 1919531    2
# 2160484    2
# 1918001    2
# 794638     2
# 1112182    2
# 467134     2
# 2845099    2
# Name: order_id, dtype: int64

# %%
# Check for all orders placed Wednesday at 2:00 AM
# Assuming 'order_dow' for Wednesday is represented by 3 and 2:00 AM is represented by 2 in 'order_hour_of_day'
wed_2am_orders = orders[(orders['order_dow'] == 3) & (orders['order_hour_of_day'] == 2)]

# Displaying the filtered orders
print("Orders placed on Wednesday at 2:00 AM:")
print()
print(wed_2am_orders)
print()
print("Count of orders placed on Wednesday at 2:00 AM:", len(wed_2am_orders))
# Out:
# Orders placed on Wednesday at 2:00 AM:
#
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838     2766110   162084            41          3                  2
# 5156     2190225   138285            18          3                  2
# 15506     553049    58599            13          3                  2
# 18420     382357   120200            19          3                  2
# 24691     690242    77357             2          3                  2
# ...          ...      ...           ...        ...                ...
# 457013   3384021    14881             6          3                  2
# 458816    910166   164782            18          3                  2
# 459635   1680532   106435             6          3                  2
# 468324    222962    54979            59          3                  2
# 477526   2592344    46860            38          3                  2
#
#         days_since_prior_order
# 4838                      16.0
# ...

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment</h2>
#
# Parameter omitted
# </div>
#
#
#
# <font color='red'> This code is used to change text color. </font>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>  Reviewer's comment ⚠️</b>
#
#
#
# It does not matter what rows we need to keep, so you can omit this parameter.
# </div>

# %%
# Double check for duplicate rows
# Verify that the duplicates have been removed by checking for duplicate 'order_id's
print("After removing duplicates, count of duplicated items:")
print(orders.duplicated(subset='order_id').sum())

print("After removal, list any order_id that appears more than once and its count:")
value_counts_after_removal = orders['order_id'].value_counts()
print(value_counts_after_removal[value_counts_after_removal > 1])
# Out:
# After removing duplicates, count of duplicated items:
# 15
# After removal, list any order_id that appears more than once and its count:
# 2125197    2
# 1782114    2
# 1286742    2
# 391768     2
# 1021560    2
# 2232988    2
# 408114     2
# 2282673    2
# 1919531    2
# 2160484    2
# 1918001    2
# 794638     2
# 1112182    2
# 467134     2
# 2845099    2
# Name: order_id, dtype: int64

# %%
# Double check for duplicate order IDs only
# Filter for order_id values that appear more than once and print
print("Duplicate order IDs (if any):")
# Verify that the duplicates have been removed by checking for duplicate 'order_id's
print("Number of duplicated 'order_id' after removal:", orders['order_id'].duplicated().sum())
# Out:
# Duplicate order IDs (if any):
# Number of duplicated 'order_id' after removal: 15

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment</h2>
#
# Printing number of duplicates
# </div>
#
#
#
# <font color='red'> This code is used to change text color. </font>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>  Reviewer's comment ⚠️</b>
#
#
#
# You can just print the number of duplicates :)
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# Looks better!
#
# </div>

# %%
# Reviewer's code 

orders[orders.duplicated(subset='order_id')]
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 145574    794638    50898            24          3                  2
# 223105   2160484   107525            16          3                  2
# 230807   1918001   188546            14          3                  2
# 266232   1782114   106752             1          3                  2
# 273805   1112182   202304            84          3                  2
# 284038   2845099    31189            11          3                  2
# 311713   1021560    53767             3          3                  2
# 321100    408114    68324             4          3                  2
# 323900   1919531   191501            32          3                  2
# 345917   2232988    82565             1          3                  2
# 371905    391768    57671            19          3                  2
# 394347    467134    63189            21          3                  2
# ...

# %% [markdown]
# ### `products` data frame

# %%
# Check for fully duplicate rows

# prints the row and product_id of each duplicate (we ignore the first copy of a duplicate)
print("Count of duplicated items:")
print(products.duplicated().sum())
# Out:
# Count of duplicated items:
# 0

# %%
# Check for just duplicate product IDs

print("List any product_id that appears more than once and its count:")
value_counts = products['product_id'].value_counts()
print(value_counts[value_counts > 1])
# Out:
# List any product_id that appears more than once and its count:
# Series([], Name: product_id, dtype: int64)

# %%
# Check for just duplicate product names (convert names to lowercase to compare better)
print("Count of duplicated product_names:")
print(products['product_name'].str.lower().duplicated().sum())
# Out:
# Count of duplicated product_names:
# 1361

# %%
# Check for duplicate product names that aren't missing
print("List any product_name that appears more than once and its count:")
value_counts = products['product_name'].str.lower().value_counts()
print(value_counts[value_counts > 1])
# Out:
# List any product_name that appears more than once and its count:
# green tea with ginseng and honey                                                                                  3
# tender white meat chicken- vegetables & rice in a cheddar cheese sauce grandma's chicken & vegetable rice bake    2
# potatoes o'brien with onions and peppers                                                                          2
# vitamin d3 2000 iu                                                                                                2
# albacore solid white tuna in water                                                                                2
#                                                                                                                  ..
# top the tater chive & onion sour cream                                                                            2
# ...

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment</h2>
#
# The analysis of the `products` DataFrame reveals no fully duplicated rows or duplicate product IDs, ensuring product identifiers' uniqueness. However, it uncovers a significant number of duplicate product names (1,361 instances), suggesting potential inconsistencies in naming or the existence of product variants with identical names. This finding highlights a need for careful consideration in analyses involving product names and possibly revising naming conventions or data entry practices to distinguish between different product variants more clearly.
# </div>
#
#
#
# <font color='red'> This code is used to change text color. </font>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# So, what can you say about these duplicates?
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>Reviewer's comment 2 ✔️</h2>
#
#
# They may have different `product_id`, so I am not sure whether we should treat them as duplicates.
#
#
# </div>

# %% [markdown]
# ### `departments` data frame

# %%
# Check for fully duplicate rows in 'departments'
print("Departments - Count of fully duplicated items:", departments.duplicated().sum())
# Out:
# Departments - Count of fully duplicated items: 0

# %%
# Check for duplicates based on 'department_id' and 'department' (there shouldn't be any, but just in case)
duplicates_department_id = departments['department_id'].duplicated().sum()
duplicates_department = departments['department'].duplicated().sum()

print("Departments - Count of duplicated 'department_id':", duplicates_department_id)
print("Departments - Count of duplicated 'department':", duplicates_department)
# Out:
# Departments - Count of duplicated 'department_id': 0
# Departments - Count of duplicated 'department': 0

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment</h2>
#
# Correction made. folowed insturctions and added code.
# </div>
#
#
#
# <font color='red'> This code is used to change text color. </font>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# > No instructions?
#
# The section is called "Find and remove duplicate values (and describe why you make your choices)", which means we are supposed to find and remove duplicates :)
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 ❌</b>
#
# Great! However, we should also check for the duplicates in `id` column. Would you do that?
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment 2</h2>
#
# Duplicates seperated.
# </div>
#
#
#
# <font color='red'> This code is used to change text color. </font>

# %% [markdown]
# ### `aisles` data frame

# %% [markdown]
# No instructions?

# %%
# Check for fully duplicate rows in 'aisles'
print("Aisles - Count of fully duplicated items:", aisles.duplicated().sum())
# Out:
# Aisles - Count of fully duplicated items: 0

# %%
# Check for duplicates based on 'aisle_id' and 'aisle'
duplicates_aisle_id = aisles['aisle_id'].duplicated().sum()
duplicates_aisle = aisles['aisle'].duplicated().sum()

print("Aisles - Count of duplicated 'aisle_id':", duplicates_aisle_id)
print("Aisles - Count of duplicated 'aisle':", duplicates_aisle)
# Out:
# Aisles - Count of duplicated 'aisle_id': 0
# Aisles - Count of duplicated 'aisle': 0

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment</h2>
#
# Correction made
# </div>
#
#
#
# <font color='red'> This code is used to change text color. </font>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment 2</h2>
#
# Seperated duplicates for both. no duplicates found
# </div>
#
#
#
# <font color='red'> This code is used to change text color. </font>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 ❌</b>
#
# Are there any duplicates in `aisle_id`?
#
# </div>
#
# ### `order_products` data frame

# %%
# Check for fullly duplicate rows
print("Count of duplicated items:")
print(order_products.duplicated().sum())
# Out:
# Count of duplicated items:
# 0

# %%
# Double check for any other tricky duplicates
# Check for duplicates in 'order_id' and 'product_id' combinations
duplicates_tricky = order_products.duplicated(subset=['order_id', 'product_id']).sum()
print("Count of 'tricky' duplicated (order_id, product_id) combinations:", duplicates_tricky)
# Out:
# Count of 'tricky' duplicated (order_id, product_id) combinations: 0

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>Reviewer's comment ✔️</h2>
#
#
# Correct.
#
# </div>

# %% [markdown]
# ## Find and remove missing values

# %% [markdown]
# ### `products` data frame

# %%
# Are all of the missing product names associated with aisle ID 100?
# Filter the DataFrame for missing product names
missing_product_names = products[products['product_name'].isna()]

# Get unique aisle IDs from the filtered DataFrame
unique_aisles_with_missing_names = missing_product_names['aisle_id'].unique()

# Check if the unique aisle IDs only contain 100
only_aisle_100 = len(unique_aisles_with_missing_names) == 1 and unique_aisles_with_missing_names[0] == 100

print("Are all missing product names associated with aisle ID 100?", only_aisle_100)
# Out:
# Are all missing product names associated with aisle ID 100? True

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
# You can make the code shorter:
#
# </div>
#
# ```python
#
# products[(products['product_name'].isna()) & (products['aisle_id'] != 100)]
# ```

# %%
# Are all of the missing product names associated with department ID 21?
# Filter the DataFrame for missing product names
missing_product_names = products[products['product_name'].isna()]

# Get unique department IDs from the filtered DataFrame
unique_departments_with_missing_names = missing_product_names['department_id'].unique()

# Check if the unique department IDs only contain 21
only_department_21 = len(unique_departments_with_missing_names) == 1 and unique_departments_with_missing_names[0] == 21

print("Are all missing product names associated with department ID 21?", only_department_21)
# Out:
# Are all missing product names associated with department ID 21? True

# %%
# What is this ailse and department?

aisle_name = aisles[aisles['aisle_id'] == 100]['aisle'].iloc[0]
department_name = departments[departments['department_id'] == 21]['department'].iloc[0]

print(f"Aisle ID 100 corresponds to the aisle: {aisle_name}")
print(f"Department ID 21 corresponds to the department: {department_name}")
# Out:
# Aisle ID 100 corresponds to the aisle: missing
# Department ID 21 corresponds to the department: missing

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
# Yes, each missing product name has a `'missing'` label.
# </div>

# %%
# Fill missing product names with 'Unknown' and explicitly reassign the column
products['product_name'] = products['product_name'].fillna('Unknown')

# Verify the change by checking if there are any more missing values in 'product_name'
print("Missing product names after filling:", products['product_name'].isna().sum())
# Out:
# Missing product names after filling: 0

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment</h2>
#
# Correction made to code. Removed inplace
# </div>
#
#
#
# <font color='red'> This code is used to change text color. </font>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ⚠️</b>
#
#
# Sometimes **inplace** does not work properly, so I'd recommend that you re-write dataframe explicitly.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>Reviewer's comment 2 ✔️</h2>
#
#
# Excellent!
# </div>

# %% [markdown]
# ### `orders` data frame

# %%
# Are there any missing values where it's not a customer's first order?
# Filter for orders beyond the first order
not_first_orders = orders[orders['order_number'] > 1]

# Count total missing values across all columns in the filtered DataFrame
total_missing_values_not_first_order = not_first_orders.isna().sum().sum()

print(f"Total number of missing values in orders that are not the customer's first order: {total_missing_values_not_first_order}")
# Out:
# Total number of missing values in orders that are not the customer's first order: 0

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
# You can make it shorter as well:
#
# </div>
#
# ```python
#
# orders[(orders['order_number'] != 1)].isna().sum()
#
#
# ```

# %% [markdown]
# ### `order_products` data frame

# %%
# What are the min and max values in this column?

min_value = order_products['add_to_cart_order'].min()
max_value = order_products['add_to_cart_order'].max()

print(f"Minimum value in 'add_to_cart_order': {min_value}")
print(f"Maximum value in 'add_to_cart_order': {max_value}")
# Out:
# Minimum value in 'add_to_cart_order': 1.0
# Maximum value in 'add_to_cart_order': 64.0

# %%
# Save all order IDs with at least one missing value in 'add_to_cart_order'
# Filtering order_ids with missing values in 'add_to_cart_order'
missing_add_to_cart_order = order_products[order_products['add_to_cart_order'].isna()]['order_id']

# Saving these order IDs
missing_add_to_cart_order_ids = missing_add_to_cart_order.unique()
print(f"Order IDs with missing 'add_to_cart_order': {missing_add_to_cart_order_ids}")
# Out:
# Order IDs with missing 'add_to_cart_order': [2449164 1968313 2926893 1717990 1959075  844733   61355  936852  264710
#  1564093  129627  293169 2849370 1386261 3308010  903110 2136777 3347453
#  1888628  165801 2094761 1038146 2997021  813364 2256933  171934 2409109
#  1730767 1169835  733526  404157 3125735  747668 1800005 1961723  871281
#   388234 1648217 1477139  102236 1021563 1832957 2721963  678116 1220886
#  1673227 2999801 1633337 2470674 2625444 1677118 2479011 3383594 1183255
#  1713430 2652650 1598369 1916118  854647 1302315  888470  180546 2621907
#  1308785 2729254    9310 2170451 2979697 1625713 1529171]

# %%
# Do all orders with missing values have more than 64 products?
# Group by 'order_id' and count the number of products
products_per_order = order_products.groupby('order_id').size()

# Filter orders with missing 'add_to_cart_order' to see if they all have more than 64 products
orders_with_missing = missing_add_to_cart_order.unique()
orders_more_than_64_products = all(products_per_order.loc[orders_with_missing] > 64)

print("Do all orders with missing 'add_to_cart_order' have more than 64 products?", orders_more_than_64_products)
# Out:
# Do all orders with missing 'add_to_cart_order' have more than 64 products? True

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
# Correct.
# </div>

# %%
# Replace missing values with 999 and convert the 'add_to_cart_order' column to integer type in one step
order_products['add_to_cart_order'] = order_products['add_to_cart_order'].fillna(999).astype(int)

# Verifying the changes by displaying the DataFrame information
order_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
# dtypes: int64(4)
# memory usage: 138.7 MB

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment</h2>
#
# Changed code. Added astype to fillna
# </div>
#
#
#
# <font color='red'> This code is used to change text color. </font>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ⚠️</b>
#
# `astype` can be applied right after `fillna`.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# Please add a conclusion about the whole section here.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment</h2>
#
# Missing Values: The process successfully identified and filled missing product names with 'Unknown', eliminating NaN values in the product_name column. This ensured that analyses involving product names could proceed without data loss due to missing entries.
#
# Duplicates: The investigation into fully duplicated rows and specific combinations of order_id and product_id helped clarify the dataset's integrity. No "tricky" duplicates were found in order_id and product_id combinations, indicating good data quality in terms of order-product relationships.
#
# Data Types: Converting the add_to_cart_order column to an integer type after replacing missing values with 999 was successfully verified. This step was crucial for ensuring that subsequent analyses would not encounter issues due to mismatched or inappropriate data types.
#
# Conclusion: The preprocessing steps effectively addressed key data quality issues, such as missing values and duplicates, and ensured the dataset was in a proper format for analysis. The dataset now provides a reliable foundation for exploring grocery shopping habits, product popularity, reorder frequencies, and other insights that can be gleaned from the Instacart dataset.
# </div>
#
#
#
# <font color='red'> This code is used to change text color. </font>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>Reviewer's comment 2 ✔️</h2>
#
#
# Great job, thank you so much!
# </div>

# %% [markdown]
# # [A] Easy (must complete all to pass)

# %% [markdown]
# ### [A1] Verify that the `'order_hour_of_day'` and `'order_dow'` values in the `orders` tables are sensible (i.e. `'order_hour_of_day'` ranges from 0 to 23 and `'order_dow'` ranges from 0 to 6)

# %%
invalid_hours = orders[(orders['order_hour_of_day'] < 0) | (orders['order_hour_of_day'] > 23)]
print(f"Invalid 'order_hour_of_day' entries: {len(invalid_hours)}")


invalid_days = orders[(orders['order_dow'] < 0) | (orders['order_dow'] > 6)]
print(f"Invalid 'order_dow' entries: {len(invalid_days)}")
# Out:
# Invalid 'order_hour_of_day' entries: 0
# Invalid 'order_dow' entries: 0

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment</h2>
#
# The analysis of the 'order_hour_of_day' and 'order_dow' columns in the orders table reveals that all entries fall within the expected ranges, with no invalid entries detected. Specifically, 'order_hour_of_day' values are all within the 0 to 23 range, and 'order_dow' values are within the 0 to 6 range. This indicates that the data for order hours and days of the week is sensible and accurately recorded, ensuring reliability for subsequent analyses related to order timing and weekly patterns.
# </div>
#
#
#
# <font color='red'> This code is used to change text color. </font>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# For each task that you have done in sections A, B and C, write a conclusion please.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>Reviewer's comment 2 ✔️</h2>
#
#
# Very good, thank you.
# </div>

# %% [markdown]
# ### [A2] What time of day do people shop for groceries?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 6))
plt.hist(orders['order_hour_of_day'], bins=24, alpha=0.7)
plt.title('Distribution of Grocery Shopping Hours')
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Orders')

plt.grid(axis='y', alpha=0.7)

plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment</h2>
#
# The histogram displaying the distribution of grocery shopping hours illustrates a clear pattern in customer order behavior throughout the day. The number of orders increases significantly in the morning hours, reaching a peak during midday, and then gradually decreases as the day progresses into the evening and night. This suggests that the majority of grocery shopping on the platform is done in the morning and early afternoon hours, with a notable decrease in activity later in the day. The presence of a peak indicates a preferred time window among customers for placing orders, which could be reflective of typical daily routines or the convenience of having groceries delivered by a certain time.
# </div>
#
#
#
# <font color='red'> This code is used to change text color. </font>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>  Reviewer's comment ⚠️</b>
#
#
# [PEP8](https://peps.python.org/pep-0008/) states that one should always put imports at the top of the file. It's a good practice, since everyone who is going to read the project, can immediately figure out what modules need to be installed. Moreover, imports should be placed in a separate cell.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
#
# Don't forget to add the conclusions.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
#
# So, most orders occur between 9 AM and 5 PM.
#
#
# </div>

# %% [markdown]
# ### [A3] What day of the week do people shop for groceries?

# %%
# Group by 'order_dow' and count the number of orders for each day using 'order_id'
day_counts = orders.groupby('order_dow')['order_id'].count()

# Generate the plot
plt.figure(figsize=(10, 6))
plt.bar(day_counts.index, day_counts, color='skyblue')

# Improving the plot with titles and labels (without custom xticks)
plt.title('Grocery Shopping Frequency by Day of Week')
plt.xlabel('Day of Week')
plt.ylabel('Number of Orders')

plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment</h2>
#
#
# The bar chart illustrating grocery shopping frequency by day of the week reveals distinct patterns in customer ordering behavior. The distribution of orders across the days shows variability, indicating that certain days are more popular for grocery shopping than others. While the plot does not specify which day corresponds to each numerical value on the x-axis, there are visible peaks and troughs suggesting that shopping activity fluctuates throughout the week. This pattern could reflect typical weekly routines, with certain days preferred for restocking groceries possibly due to factors like work schedules, weekly promotions, or preparation for weekend meals. The visualization underscores the importance of understanding daily trends in customer orders to optimize inventory and delivery logistics.
# </div>
#
#
#
# <font color='red'> This code is used to change text color. </font>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment</h2>
#
#
# removed import from code.
# </div>
#
#
#
# <font color='red'> This code is used to change text color. </font>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>  Reviewer's comment ⚠️</b>
#
#
# The module can be imported only once.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
#
# Good.
#
# </div>

# %% [markdown]
# ### [A4] How long do people wait until placing another order?

# %%
import matplotlib.pyplot as plt

# %%
# Ensure the 'days_since_prior_order' column is not missing for this analysis
# Create a histogram for 'days_since_prior_order'
plt.figure(figsize=(12, 6))
plt.hist(orders['days_since_prior_order'].dropna(), bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Days Since Prior Order')
plt.xlabel('Days Since Prior Order')
plt.ylabel('Number of Orders')
  

plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment</h2>
#
#
# The histogram displaying the distribution of days since prior order highlights the variability in the time intervals customers wait before placing another order. There are distinct peaks at certain intervals, notably around 7 days and at the 30-day mark, indicating a tendency for customers to place orders on a weekly basis or at the end of the month. This pattern might reflect routine grocery restocking or subscription-based ordering behaviors. The distribution also shows a relatively continuous ordering activity between these peaks, suggesting that while some customers adhere to a regular ordering schedule, others have more sporadic ordering patterns. Overall, this analysis reveals the diversity in customer ordering frequencies and suggests the presence of both routine and as-needed shopping behaviors among the platform's users.
# </div>
#
#
#
# <font color='red'> This code is used to change text color. </font>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
#
# Some people may make an order once a month.
# </div>

# %% [markdown]
# # [B] Medium (must complete all to pass)

# %% [markdown]
# ### [B1] Is there a difference in `'order_hour_of_day'` distributions on Wednesdays and Saturdays? Plot the histograms for both days and describe the differences that you see.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Assuming 'orders' DataFrame is loaded and 'order_dow' for Wednesday is 3 and for Saturday is 6
wednesday_orders = orders[orders['order_dow'] == 3]
saturday_orders = orders[orders['order_dow'] == 6]

plt.figure(figsize=(14, 7))

# Plotting both histograms on the same chart for direct comparison
sns.histplot(wednesday_orders['order_hour_of_day'], bins=24, kde=False, color="skyblue", label='Wednesday', alpha=0.6)
sns.histplot(saturday_orders['order_hour_of_day'], bins=24, kde=False, color="orange", label='Saturday', alpha=0.6)

# Adding titles and labels for clarity, with an updated y-axis label
plt.title('Order Hour Distribution on Wednesday vs. Saturday', fontsize=16)
plt.xlabel('Hour of Day', fontsize=14)
plt.ylabel('Number of Orders', fontsize=14)  # Updated for clarity

# Adding a legend to distinguish between the days
plt.legend(title='Day of Week', fontsize=12)

plt.grid(axis='y', alpha=0.5)  # Adding grid lines for better readability
plt.xticks(fontsize=12)  # Adjusting x-axis label font size for better readability
plt.yticks(fontsize=12)  # Adjusting y-axis label font size for better readability

plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment</h2>
#
#
# The comparison of order hour distributions between Wednesday and Saturday reveals notable differences in customer ordering patterns. On both days, there is a common trend of orders starting to increase in the morning, peaking during the midday to early afternoon hours, and then gradually declining towards the evening. However, Saturday shows a more pronounced peak and higher overall order volumes compared to Wednesday, indicating that more customers prefer to do their grocery shopping on Saturdays. The presence of a broader distribution on Saturday also suggests that ordering activity is more spread out throughout the day, possibly reflecting more flexible schedules on weekends. The histograms underscore the importance of understanding daily variations in ordering behavior to optimize service and delivery strategies for different days of the week.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment</h2>
#
# changed labels

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
#
# `Count` label may seem unclear for a reader. Please make sure that each chart has lucid labels and titles.
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>  Reviewer's comment ⚠️</b>
#
#
# Would you try to display these histograms on one chart?
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
#
# Very good!
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>  Reviewer's comment 2 ⚠️</h2>
#
#
# You can just write "Number of orders". It is much better than "Frequency".
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment 2</h2>
#
# removed frecuency for the ylabel.

# %% [markdown]
# ### [B2] What's the distribution for the number of orders per customer?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Group by 'user_id' and count the number of orders for each customer
orders_per_customer = orders.groupby('user_id').size()

# Plot the distribution of orders per customer without xlim
plt.figure(figsize=(12, 6))
sns.histplot(orders_per_customer, bins=30, kde=False, color='skyblue')
plt.title('Distribution of Orders Per Customer')
plt.xlabel('Number of Orders')
plt.ylabel('Number of Customers')

plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment</h2>
#
#
# The histogram depicting the distribution of orders per customer showcases a wide range of ordering behaviors among customers on the platform. Most customers have placed a relatively low number of orders, as indicated by the high frequency of customers in the lower bins of the histogram. This suggests that a significant portion of customers may be new to the platform or use it infrequently. However, there is a long tail to the right, indicating that a smaller, yet notable, number of customers place a high volume of orders. These could represent highly engaged or long-term users who rely heavily on the service for their grocery needs. The distribution highlights the diverse customer base of the platform, from infrequent users to those with potentially strong loyalty and frequent ordering habits.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
#
# Seems like most people usually have no more than 10 orders.
#
# </div>

# %% [markdown]
# ### [B3] What are the top 20 popular products (display their id and name)?

# %%
# Count the number of orders for each product
product_order_counts = order_products['product_id'].value_counts().reset_index(name='order_count')
product_order_counts.columns = ['product_id', 'order_count']

# Merge with the products DataFrame to get product names
popular_products = pd.merge(product_order_counts, products, on='product_id')

# Sort by order_count to get the top 20 most popular products
top_20_popular_products = popular_products.sort_values('order_count', ascending=False).head(20)

# Display the top 20 popular products with their IDs and names
print(top_20_popular_products[['product_id', 'product_name', 'order_count']])
# Out:
#     product_id              product_name  order_count
# 0        24852                    Banana        66050
# 1        13176    Bag of Organic Bananas        53297
# 2        21137      Organic Strawberries        37039
# 3        21903      Organic Baby Spinach        33971
# 4        47209      Organic Hass Avocado        29773
# 5        47766           Organic Avocado        24689
# 6        47626               Large Lemon        21495
# 7        16797              Strawberries        20018
# 8        26209                     Limes        19690
# 9        27845        Organic Whole Milk        19600
# 10       27966       Organic Raspberries        19197
# 11       22935      Organic Yellow Onion        15898
# 12       24964            Organic Garlic        15292
# 13       45007          Organic Zucchini        14584
# 14       39275       Organic Blueberries        13879
# 15       49683            Cucumber Kirby        13675
# ...

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment</h2>
#
#
# The analysis identifying the top 20 most popular products on the platform reveals a diverse range of items that are frequently ordered by customers. By merging order counts with product names and focusing on those with the highest order counts, the data provides a clear picture of consumer preferences and shopping behavior. These top 20 products, characterized by their high frequency in customer orders, likely reflect staple items or those with broad appeal, indicating their importance in the average grocery shopping list. This insight is valuable for understanding key drivers of demand on the platform, assisting in inventory management, and tailoring marketing strategies to highlight these popular choices. The list of top products underscores the platform's role in providing essential grocery items to its user base.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
#
# Everything looks correct.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# It will be perfect after you add conclusions.
#
# </div>

# %% [markdown]
# # [C] Hard (must complete at least two to pass)

# %% [markdown]
# 2.11[C1] How many items do people typically buy in one order? What does the distribution look like?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Count the number of items in each order
items_per_order = order_products.groupby('order_id').size()

# Analyze the distribution of items per order
plt.figure(figsize=(12, 6))
sns.histplot(items_per_order, bins=30, kde=True, color='skyblue')
plt.title('Distribution of Number of Items Purchased per Order')
plt.xlabel('Number of Items')
plt.ylabel('Number of Orders')

plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment</h2>
#
#
# The histogram exploring the distribution of the number of items purchased per order illustrates that the majority of orders contain a relatively small number of items, indicating a preference or necessity among customers for placing orders with fewer items. The presence of a kernel density estimate (KDE) overlay on the histogram reveals the smooth distribution curve, which sharply peaks at lower item counts and gradually tails off as the number of items increases. This pattern suggests that while most orders are modest in size, there is a wide variation in order sizes across the platform, with some orders containing significantly more items. The distribution underscores the diverse shopping needs and habits of the platform's users, ranging from small, possibly routine or specific purchases to larger, possibly bulk or comprehensive shopping trips.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
#
# Great!
# </div>

# %% [markdown]
# ### [C2] What are the top 20 items that are reordered most frequently (display their names and product IDs)?

# %%
reorder_frequencies = order_products.groupby('product_id')['reordered'].sum().reset_index()


reorder_frequencies = pd.merge(reorder_frequencies, products, on='product_id')


top_20_reorders = reorder_frequencies.sort_values(by='reordered', ascending=False).head(20)

# Display the top 20 reordered products
print(top_20_reorders[['product_id', 'product_name', 'reordered']])
# Out:
#        product_id              product_name  reordered
# 22808       24852                    Banana      55763
# 12025       13176    Bag of Organic Bananas      44450
# 19370       21137      Organic Strawberries      28639
# 20077       21903      Organic Baby Spinach      26233
# 43271       47209      Organic Hass Avocado      23629
# 43788       47766           Organic Avocado      18743
# 25556       27845        Organic Whole Milk      16251
# 43663       47626               Large Lemon      15044
# 25666       27966       Organic Raspberries      14748
# 15364       16797              Strawberries      13945
# 24047       26209                     Limes      13327
# 21025       22935      Organic Yellow Onion      11145
# 22908       24964            Organic Garlic      10411
# 41244       45007          Organic Zucchini      10076
# 45561       49683            Cucumber Kirby       9538
# 25889       28204        Organic Fuji Apple       8989
# ...

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment</h2>
#
#
# The analysis of the top 20 items that are reordered most frequently reveals that certain products have a particularly high repeat purchase rate, showcasing their essential role in the shopping habits of the platform's users. By merging reorder frequencies with product names, the data highlights these popular items, suggesting their importance and consistent demand among customers. These top 20 products, which span a variety of categories, reflect the trust and preference customers place in them, possibly due to their quality, necessity, or both. The high reorder rates for these items indicate that they are likely staples in many households, integral to regular shopping lists. Understanding these reorder patterns is crucial for inventory management, ensuring these high-demand products are always available to meet customer expectations and drive customer satisfaction and loyalty.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# Don't forget about the conclusions for this part as well.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
#
# Correct.
#
# </div>

# %% [markdown]
# ### [C3] For each product, what proportion of its orders are reorders?

# %% [markdown]
# ### [C4] For each customer, what proportion of their products ordered are reorders?

# %% [markdown]
# ### [C5] What are the top 20 items that people put in their carts first?

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# Please add the overall conclusion to your project: what have been done and what can be inferred from the results.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment</h2>
#
# In this project, we analyzed Instacart's grocery shopping data to understand consumer behavior. After cleaning the data by addressing missing values and duplicates, we explored shopping patterns, product popularity, and order sizes. Our findings reveal peak shopping times and days, highlight staple products with high reorder frequencies, and indicate varying order sizes that suggest different shopping needs. From these results, we infer that customer preferences and routines significantly influence shopping behavior on Instacart. These insights can guide targeted marketing strategies, inventory management, and enhance the shopping experience, demonstrating the value of data-driven decision-making in retail operations.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
#
# Awesome job, thank you so much!
# </div>
